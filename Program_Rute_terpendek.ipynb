# %% [markdown]
# **Program Rute Terpendek dengan Algoritma Brute Force**
#
# Disusun oleh:
#
#
# 1.   Fila Sofiyati
# 2.   Merlinda Lavenia
# 3. Silvi Nuraida

# %% [markdown]
# **Merupakan Rute Terpendek Tempat Wisata Bersejarah di Semarang (Kota dan Kabupaten Semarang)**
# Dengan list tempat sebagai berikut:
#
#
#
# 0.   Tugu Muda
# 1.	Lawang Sewu
# 2.	Museum Kota Lama Semarang
# 3.	Museum Rekor Dunia Indonesia
# 4.	Sam Poo Kong
# 5.	Candi Gedong Songo
# 6.	Museum Perjuangan Mandala Bakti
# 7.	Benteng Pendem Ambarawa
# 8.	Museum Kereta Api Ambarawa
# 9.	Pagoda Avalokitesvara
#
# Untuk titik awalnya kami mencoba satu per satu sedemikian hingga ditemukan rute terpendeknya.
#
# Untuk detail jaraknya yaitu:
#
#
#     [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
#     [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
#     [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
#     [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
#     [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
#     [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
#     [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
#     [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
#     [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
#     [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],

# %% [markdown]
# **Kesimpulanya**
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 2 Ke 1, Jarak: 3 Km
# Dari 1 Ke 0, Jarak: 0.15 Km
# Dari 0 Ke 6, Jarak: 0.064 Km
# Dari 6 Ke 4, Jarak: 2.5 Km
# Dari 4 Ke 3, Jarak: 11.4 Km
# Dari 3 Ke 9, Jarak: 2.1 Km
# Dari 9 Ke 7, Jarak: 24.5 Km
# Dari 7 Ke 8, Jarak: 1 Km
# Dari 8 Ke 5, Jarak: 12.8 Km
#
# Rute Terpendek:
# 2 -> 1 -> 0 -> 6 -> 4 -> 3 -> 9 -> 7 -> 8 -> 5
# Total Jarak: 57.513999999999996 Km
#
# **Nilai optimal perolehan jarak , terpendeknya dan detail rutenya yaitu 57,51 Km, dengan detail rute destinasi wisata yaitu Museum Kota Lama Semarang - Lawang Sewu - Tugu Muda - Museum Perjuangan Mandala Bhakti - Sam Poo Kong - Museum Rekor Dunia Indonesia - Pagoda Avalokitesvara - Benteng Pendem Ambarawa - Museum Kereta Api Ambarawa - Candi Gedong Songo.**

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Matriks berdasarkan data yang diberikan
matrix = [
   [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]


# Buat graf menggunakan NetworkX
G = nx.Graph()

# Tambahkan edge dan beri atribut weight
for i in range(len(matrix)):
    for j in range(len(matrix[i])):
        if matrix[i][j] != 0:
            G.add_edge(i, j, weight=matrix[i][j])

# Gambar graf dengan penyesuaian skala, ukuran node, dan font size
fig, ax = plt.subplots(figsize=(15, 12))  # Atur ukuran gambar

pos = nx.spring_layout(G)  # Tentukan layout
labels = nx.get_edge_attributes(G, 'weight')  # Atribut weight sebagai label

# Penyesuaian ukuran dan fontsize
nx.draw(G, pos, with_labels=True, font_size=9, node_size=500, font_weight='bold', node_color='yellow')
edge_labels = nx.draw_networkx_edge_labels(G, pos, edge_labels=labels, font_size=9, font_weight='bold')  # Penyesuaian font size

plt.show()

# %%
from itertools import permutations

class Graph():
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)] for row in range(vertices)]

    def printSolution(self, path, dist):
        print("Detail jarak (Km) titik satu ke titik lainnya:")
        total_dist = 0

        # Mencetak detail jarak antar titik
        for i in range(len(path) - 1):
            from_node, to_node = path[i], path[i + 1]
            leg_dist = self.graph[from_node][to_node]
            total_dist += leg_dist
            print(f"Dari {from_node} Ke {to_node}, Jarak: {leg_dist} Km")

        print("\nRute Terpendek:")
        print(" -> ".join(map(str, path)))
        print(f"Total Jarak: {total_dist} Km")

    def tsp(self):
        # Menetapkan titik awal sebagai 0
        start = 0

        # Membuat list semua titik kecuali titik awal
        vertices = [i for i in range(self.V) if i != start]

        # Menyimpan semua rute yang mungkin
        all_routes = permutations(vertices)

        min_dist = float('inf')
        min_path = None

        for route in all_routes:
            current_path = [start] + list(route)
            current_dist = 0

            # Menghitung total jarak untuk rute saat ini
            for i in range(self.V - 1):
                current_dist += self.graph[current_path[i]][current_path[i+1]]

            # Memperbarui rute terpendek
            if current_dist < min_dist:
                min_dist = current_dist
                min_path = current_path

        # Cetak rute terpendek dan detailnya setelah iterasi selesai
        self.printSolution(min_path, min_dist)

# Driver program
g = Graph(10)
g.graph = [
    [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]

g.tsp()
# Out:
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 0 Ke 6, Jarak: 0.064 Km
# Dari 6 Ke 2, Jarak: 3.3 Km
# Dari 2 Ke 1, Jarak: 3 Km
# Dari 1 Ke 4, Jarak: 2.5 Km
# Dari 4 Ke 3, Jarak: 11.4 Km
# Dari 3 Ke 9, Jarak: 2.1 Km
# Dari 9 Ke 7, Jarak: 24.5 Km
# Dari 7 Ke 8, Jarak: 1 Km
# Dari 8 Ke 5, Jarak: 12.8 Km
#
# Rute Terpendek:
# 0 -> 6 -> 2 -> 1 -> 4 -> 3 -> 9 -> 7 -> 8 -> 5
# Total Jarak: 60.664 Km

# %%
from itertools import permutations

class Graph():
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)] for row in range(vertices)]

    def printSolution(self, path, dist):
        print("Detail jarak (Km) titik satu ke titik lainnya:")
        total_dist = 0

        # Mencetak detail jarak antar titik
        for i in range(len(path) - 1):
            from_node, to_node = path[i], path[i + 1]
            leg_dist = self.graph[from_node][to_node]
            total_dist += leg_dist
            print(f"Dari {from_node} Ke {to_node}, Jarak: {leg_dist} Km")

        print("\nRute Terpendek:")
        print(" -> ".join(map(str, path)))
        print(f"Total Jarak: {total_dist} Km")

    def tsp(self):
        # Menetapkan titik awal sebagai 0
        start = 1

        # Membuat list semua titik kecuali titik awal
        vertices = [i for i in range(self.V) if i != start]

        # Menyimpan semua rute yang mungkin
        all_routes = permutations(vertices)

        min_dist = float('inf')
        min_path = None

        for route in all_routes:
            current_path = [start] + list(route)
            current_dist = 0

            # Menghitung total jarak untuk rute saat ini
            for i in range(self.V - 1):
                current_dist += self.graph[current_path[i]][current_path[i+1]]

            # Memperbarui rute terpendek
            if current_dist < min_dist:
                min_dist = current_dist
                min_path = current_path

        # Cetak rute terpendek dan detailnya setelah iterasi selesai
        self.printSolution(min_path, min_dist)

# Driver program
g = Graph(10)
g.graph = [
    [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]

g.tsp()
# Out:
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 1 Ke 2, Jarak: 3.2 Km
# Dari 2 Ke 0, Jarak: 3.3 Km
# Dari 0 Ke 6, Jarak: 0.064 Km
# Dari 6 Ke 4, Jarak: 2.5 Km
# Dari 4 Ke 3, Jarak: 11.4 Km
# Dari 3 Ke 9, Jarak: 2.1 Km
# Dari 9 Ke 7, Jarak: 24.5 Km
# Dari 7 Ke 8, Jarak: 1 Km
# Dari 8 Ke 5, Jarak: 12.8 Km
#
# Rute Terpendek:
# 1 -> 2 -> 0 -> 6 -> 4 -> 3 -> 9 -> 7 -> 8 -> 5
# Total Jarak: 60.864000000000004 Km

# %%
from itertools import permutations

class Graph():
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)] for row in range(vertices)]

    def printSolution(self, path, dist):
        print("Detail jarak (Km) titik satu ke titik lainnya:")
        total_dist = 0

        # Mencetak detail jarak antar titik
        for i in range(len(path) - 1):
            from_node, to_node = path[i], path[i + 1]
            leg_dist = self.graph[from_node][to_node]
            total_dist += leg_dist
            print(f"Dari {from_node} Ke {to_node}, Jarak: {leg_dist} Km")

        print("\nRute Terpendek:")
        print(" -> ".join(map(str, path)))
        print(f"Total Jarak: {total_dist} Km")

    def tsp(self):
        # Menetapkan titik awal sebagai 0
        start = 2

        # Membuat list semua titik kecuali titik awal
        vertices = [i for i in range(self.V) if i != start]

        # Menyimpan semua rute yang mungkin
        all_routes = permutations(vertices)

        min_dist = float('inf')
        min_path = None

        for route in all_routes:
            current_path = [start] + list(route)
            current_dist = 0

            # Menghitung total jarak untuk rute saat ini
            for i in range(self.V - 1):
                current_dist += self.graph[current_path[i]][current_path[i+1]]

            # Memperbarui rute terpendek
            if current_dist < min_dist:
                min_dist = current_dist
                min_path = current_path

        # Cetak rute terpendek dan detailnya setelah iterasi selesai
        self.printSolution(min_path, min_dist)

# Driver program
g = Graph(10)
g.graph = [
    [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]

g.tsp()
# Out:
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 2 Ke 1, Jarak: 3 Km
# Dari 1 Ke 0, Jarak: 0.15 Km
# Dari 0 Ke 6, Jarak: 0.064 Km
# Dari 6 Ke 4, Jarak: 2.5 Km
# Dari 4 Ke 3, Jarak: 11.4 Km
# Dari 3 Ke 9, Jarak: 2.1 Km
# Dari 9 Ke 7, Jarak: 24.5 Km
# Dari 7 Ke 8, Jarak: 1 Km
# Dari 8 Ke 5, Jarak: 12.8 Km
#
# Rute Terpendek:
# 2 -> 1 -> 0 -> 6 -> 4 -> 3 -> 9 -> 7 -> 8 -> 5
# Total Jarak: 57.513999999999996 Km

# %%
from itertools import permutations

class Graph():
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)] for row in range(vertices)]

    def printSolution(self, path, dist):
        print("Detail jarak (Km) titik satu ke titik lainnya:")
        total_dist = 0

        # Mencetak detail jarak antar titik
        for i in range(len(path) - 1):
            from_node, to_node = path[i], path[i + 1]
            leg_dist = self.graph[from_node][to_node]
            total_dist += leg_dist
            print(f"Dari {from_node} Ke {to_node}, Jarak: {leg_dist} Km")

        print("\nRute Terpendek:")
        print(" -> ".join(map(str, path)))
        print(f"Total Jarak: {total_dist} Km")

    def tsp(self):
        # Menetapkan titik awal sebagai 0
        start = 3

        # Membuat list semua titik kecuali titik awal
        vertices = [i for i in range(self.V) if i != start]

        # Menyimpan semua rute yang mungkin
        all_routes = permutations(vertices)

        min_dist = float('inf')
        min_path = None

        for route in all_routes:
            current_path = [start] + list(route)
            current_dist = 0

            # Menghitung total jarak untuk rute saat ini
            for i in range(self.V - 1):
                current_dist += self.graph[current_path[i]][current_path[i+1]]

            # Memperbarui rute terpendek
            if current_dist < min_dist:
                min_dist = current_dist
                min_path = current_path

        # Cetak rute terpendek dan detailnya setelah iterasi selesai
        self.printSolution(min_path, min_dist)

# Driver program
g = Graph(10)
g.graph = [
    [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]

g.tsp()
# Out:
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 3 Ke 2, Jarak: 12.4 Km
# Dari 2 Ke 1, Jarak: 3 Km
# Dari 1 Ke 0, Jarak: 0.15 Km
# Dari 0 Ke 6, Jarak: 0.064 Km
# Dari 6 Ke 4, Jarak: 2.5 Km
# Dari 4 Ke 9, Jarak: 13 Km
# Dari 9 Ke 7, Jarak: 24.5 Km
# Dari 7 Ke 8, Jarak: 1 Km
# Dari 8 Ke 5, Jarak: 12.8 Km
#
# Rute Terpendek:
# 3 -> 2 -> 1 -> 0 -> 6 -> 4 -> 9 -> 7 -> 8 -> 5
# Total Jarak: 69.414 Km

# %%
from itertools import permutations

class Graph():
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)] for row in range(vertices)]

    def printSolution(self, path, dist):
        print("Detail jarak (Km) titik satu ke titik lainnya:")
        total_dist = 0

        # Mencetak detail jarak antar titik
        for i in range(len(path) - 1):
            from_node, to_node = path[i], path[i + 1]
            leg_dist = self.graph[from_node][to_node]
            total_dist += leg_dist
            print(f"Dari {from_node} Ke {to_node}, Jarak: {leg_dist} Km")

        print("\nRute Terpendek:")
        print(" -> ".join(map(str, path)))
        print(f"Total Jarak: {total_dist} Km")

    def tsp(self):
        # Menetapkan titik awal sebagai 0
        start = 4

        # Membuat list semua titik kecuali titik awal
        vertices = [i for i in range(self.V) if i != start]

        # Menyimpan semua rute yang mungkin
        all_routes = permutations(vertices)

        min_dist = float('inf')
        min_path = None

        for route in all_routes:
            current_path = [start] + list(route)
            current_dist = 0

            # Menghitung total jarak untuk rute saat ini
            for i in range(self.V - 1):
                current_dist += self.graph[current_path[i]][current_path[i+1]]

            # Memperbarui rute terpendek
            if current_dist < min_dist:
                min_dist = current_dist
                min_path = current_path

        # Cetak rute terpendek dan detailnya setelah iterasi selesai
        self.printSolution(min_path, min_dist)

# Driver program
g = Graph(10)
g.graph = [
    [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]

g.tsp()
# Out:
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 4 Ke 6, Jarak: 2.3 Km
# Dari 6 Ke 0, Jarak: 0.027 Km
# Dari 0 Ke 1, Jarak: 0.23 Km
# Dari 1 Ke 2, Jarak: 3.2 Km
# Dari 2 Ke 3, Jarak: 13 Km
# Dari 3 Ke 9, Jarak: 2.1 Km
# Dari 9 Ke 7, Jarak: 24.5 Km
# Dari 7 Ke 8, Jarak: 1 Km
# Dari 8 Ke 5, Jarak: 12.8 Km
#
# Rute Terpendek:
# 4 -> 6 -> 0 -> 1 -> 2 -> 3 -> 9 -> 7 -> 8 -> 5
# Total Jarak: 59.157 Km

# %%
from itertools import permutations

class Graph():
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)] for row in range(vertices)]

    def printSolution(self, path, dist):
        print("Detail jarak (Km) titik satu ke titik lainnya:")
        total_dist = 0

        # Mencetak detail jarak antar titik
        for i in range(len(path) - 1):
            from_node, to_node = path[i], path[i + 1]
            leg_dist = self.graph[from_node][to_node]
            total_dist += leg_dist
            print(f"Dari {from_node} Ke {to_node}, Jarak: {leg_dist} Km")

        print("\nRute Terpendek:")
        print(" -> ".join(map(str, path)))
        print(f"Total Jarak: {total_dist} Km")

    def tsp(self):
        # Menetapkan titik awal sebagai 0
        start = 5

        # Membuat list semua titik kecuali titik awal
        vertices = [i for i in range(self.V) if i != start]

        # Menyimpan semua rute yang mungkin
        all_routes = permutations(vertices)

        min_dist = float('inf')
        min_path = None

        for route in all_routes:
            current_path = [start] + list(route)
            current_dist = 0

            # Menghitung total jarak untuk rute saat ini
            for i in range(self.V - 1):
                current_dist += self.graph[current_path[i]][current_path[i+1]]

            # Memperbarui rute terpendek
            if current_dist < min_dist:
                min_dist = current_dist
                min_path = current_path

        # Cetak rute terpendek dan detailnya setelah iterasi selesai
        self.printSolution(min_path, min_dist)

# Driver program
g = Graph(10)
g.graph = [
    [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]

g.tsp()
# Out:
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 5 Ke 8, Jarak: 12.8 Km
# Dari 8 Ke 7, Jarak: 1.5 Km
# Dari 7 Ke 9, Jarak: 24 Km
# Dari 9 Ke 3, Jarak: 2.5 Km
# Dari 3 Ke 4, Jarak: 11.2 Km
# Dari 4 Ke 6, Jarak: 2.3 Km
# Dari 6 Ke 0, Jarak: 0.027 Km
# Dari 0 Ke 1, Jarak: 0.23 Km
# Dari 1 Ke 2, Jarak: 3.2 Km
#
# Rute Terpendek:
# 5 -> 8 -> 7 -> 9 -> 3 -> 4 -> 6 -> 0 -> 1 -> 2
# Total Jarak: 57.757 Km

# %%
from itertools import permutations

class Graph():
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)] for row in range(vertices)]

    def printSolution(self, path, dist):
        print("Detail jarak (Km) titik satu ke titik lainnya:")
        total_dist = 0

        # Mencetak detail jarak antar titik
        for i in range(len(path) - 1):
            from_node, to_node = path[i], path[i + 1]
            leg_dist = self.graph[from_node][to_node]
            total_dist += leg_dist
            print(f"Dari {from_node} Ke {to_node}, Jarak: {leg_dist} Km")

        print("\nRute Terpendek:")
        print(" -> ".join(map(str, path)))
        print(f"Total Jarak: {total_dist} Km")

    def tsp(self):
        # Menetapkan titik awal sebagai 0
        start = 6

        # Membuat list semua titik kecuali titik awal
        vertices = [i for i in range(self.V) if i != start]

        # Menyimpan semua rute yang mungkin
        all_routes = permutations(vertices)

        min_dist = float('inf')
        min_path = None

        for route in all_routes:
            current_path = [start] + list(route)
            current_dist = 0

            # Menghitung total jarak untuk rute saat ini
            for i in range(self.V - 1):
                current_dist += self.graph[current_path[i]][current_path[i+1]]

            # Memperbarui rute terpendek
            if current_dist < min_dist:
                min_dist = current_dist
                min_path = current_path

        # Cetak rute terpendek dan detailnya setelah iterasi selesai
        self.printSolution(min_path, min_dist)

# Driver program
g = Graph(10)
g.graph = [
    [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]

g.tsp()
# Out:
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 6 Ke 0, Jarak: 0.027 Km
# Dari 0 Ke 2, Jarak: 3.3 Km
# Dari 2 Ke 1, Jarak: 3 Km
# Dari 1 Ke 4, Jarak: 2.5 Km
# Dari 4 Ke 3, Jarak: 11.4 Km
# Dari 3 Ke 9, Jarak: 2.1 Km
# Dari 9 Ke 7, Jarak: 24.5 Km
# Dari 7 Ke 8, Jarak: 1 Km
# Dari 8 Ke 5, Jarak: 12.8 Km
#
# Rute Terpendek:
# 6 -> 0 -> 2 -> 1 -> 4 -> 3 -> 9 -> 7 -> 8 -> 5
# Total Jarak: 60.626999999999995 Km

# %%
from itertools import permutations

class Graph():
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)] for row in range(vertices)]

    def printSolution(self, path, dist):
        print("Detail jarak (Km) titik satu ke titik lainnya:")
        total_dist = 0

        # Mencetak detail jarak antar titik
        for i in range(len(path) - 1):
            from_node, to_node = path[i], path[i + 1]
            leg_dist = self.graph[from_node][to_node]
            total_dist += leg_dist
            print(f"Dari {from_node} Ke {to_node}, Jarak: {leg_dist} Km")

        print("\nRute Terpendek:")
        print(" -> ".join(map(str, path)))
        print(f"Total Jarak: {total_dist} Km")

    def tsp(self):
        # Menetapkan titik awal sebagai 0
        start = 7

        # Membuat list semua titik kecuali titik awal
        vertices = [i for i in range(self.V) if i != start]

        # Menyimpan semua rute yang mungkin
        all_routes = permutations(vertices)

        min_dist = float('inf')
        min_path = None

        for route in all_routes:
            current_path = [start] + list(route)
            current_dist = 0

            # Menghitung total jarak untuk rute saat ini
            for i in range(self.V - 1):
                current_dist += self.graph[current_path[i]][current_path[i+1]]

            # Memperbarui rute terpendek
            if current_dist < min_dist:
                min_dist = current_dist
                min_path = current_path

        # Cetak rute terpendek dan detailnya setelah iterasi selesai
        self.printSolution(min_path, min_dist)

# Driver program
g = Graph(10)
g.graph = [
    [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]

g.tsp()
# Out:
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 7 Ke 8, Jarak: 1 Km
# Dari 8 Ke 5, Jarak: 12.8 Km
# Dari 5 Ke 9, Jarak: 26.1 Km
# Dari 9 Ke 3, Jarak: 2.5 Km
# Dari 3 Ke 4, Jarak: 11.2 Km
# Dari 4 Ke 6, Jarak: 2.3 Km
# Dari 6 Ke 0, Jarak: 0.027 Km
# Dari 0 Ke 1, Jarak: 0.23 Km
# Dari 1 Ke 2, Jarak: 3.2 Km
#
# Rute Terpendek:
# 7 -> 8 -> 5 -> 9 -> 3 -> 4 -> 6 -> 0 -> 1 -> 2
# Total Jarak: 59.357000000000006 Km

# %%
from itertools import permutations

class Graph():
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)] for row in range(vertices)]

    def printSolution(self, path, dist):
        print("Detail jarak (Km) titik satu ke titik lainnya:")
        total_dist = 0

        # Mencetak detail jarak antar titik
        for i in range(len(path) - 1):
            from_node, to_node = path[i], path[i + 1]
            leg_dist = self.graph[from_node][to_node]
            total_dist += leg_dist
            print(f"Dari {from_node} Ke {to_node}, Jarak: {leg_dist} Km")

        print("\nRute Terpendek:")
        print(" -> ".join(map(str, path)))
        print(f"Total Jarak: {total_dist} Km")

    def tsp(self):
        # Menetapkan titik awal sebagai 0
        start = 8

        # Membuat list semua titik kecuali titik awal
        vertices = [i for i in range(self.V) if i != start]

        # Menyimpan semua rute yang mungkin
        all_routes = permutations(vertices)

        min_dist = float('inf')
        min_path = None

        for route in all_routes:
            current_path = [start] + list(route)
            current_dist = 0

            # Menghitung total jarak untuk rute saat ini
            for i in range(self.V - 1):
                current_dist += self.graph[current_path[i]][current_path[i+1]]

            # Memperbarui rute terpendek
            if current_dist < min_dist:
                min_dist = current_dist
                min_path = current_path

        # Cetak rute terpendek dan detailnya setelah iterasi selesai
        self.printSolution(min_path, min_dist)

# Driver program
g = Graph(10)
g.graph = [
    [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]

g.tsp()
# Out:
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 8 Ke 7, Jarak: 1.5 Km
# Dari 7 Ke 5, Jarak: 13.5 Km
# Dari 5 Ke 9, Jarak: 26.1 Km
# Dari 9 Ke 3, Jarak: 2.5 Km
# Dari 3 Ke 4, Jarak: 11.2 Km
# Dari 4 Ke 6, Jarak: 2.3 Km
# Dari 6 Ke 0, Jarak: 0.027 Km
# Dari 0 Ke 1, Jarak: 0.23 Km
# Dari 1 Ke 2, Jarak: 3.2 Km
#
# Rute Terpendek:
# 8 -> 7 -> 5 -> 9 -> 3 -> 4 -> 6 -> 0 -> 1 -> 2
# Total Jarak: 60.556999999999995 Km

# %%
from itertools import permutations

class Graph():
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)] for row in range(vertices)]

    def printSolution(self, path, dist):
        print("Detail jarak (Km) titik satu ke titik lainnya:")
        total_dist = 0

        # Mencetak detail jarak antar titik
        for i in range(len(path) - 1):
            from_node, to_node = path[i], path[i + 1]
            leg_dist = self.graph[from_node][to_node]
            total_dist += leg_dist
            print(f"Dari {from_node} Ke {to_node}, Jarak: {leg_dist} Km")

        print("\nRute Terpendek:")
        print(" -> ".join(map(str, path)))
        print(f"Total Jarak: {total_dist} Km")

    def tsp(self):
        # Menetapkan titik awal sebagai 0
        start = 9

        # Membuat list semua titik kecuali titik awal
        vertices = [i for i in range(self.V) if i != start]

        # Menyimpan semua rute yang mungkin
        all_routes = permutations(vertices)

        min_dist = float('inf')
        min_path = None

        for route in all_routes:
            current_path = [start] + list(route)
            current_dist = 0

            # Menghitung total jarak untuk rute saat ini
            for i in range(self.V - 1):
                current_dist += self.graph[current_path[i]][current_path[i+1]]

            # Memperbarui rute terpendek
            if current_dist < min_dist:
                min_dist = current_dist
                min_path = current_path

        # Cetak rute terpendek dan detailnya setelah iterasi selesai
        self.printSolution(min_path, min_dist)

# Driver program
g = Graph(10)
g.graph = [
    [0, 0.23, 3.3, 11.7, 2.8, 38.8, 0.064, 37.9, 38.6, 13.3],
    [0.15, 0, 3.2, 11.5, 2.5, 38.6, 0.17, 37.6, 38.4, 13.1],
    [3.3, 3, 0, 13, 5.7, 40, 3.3, 39.1, 39.8, 14.6],
    [11.1, 11.3, 12.4, 0, 11.2, 27.6, 11.1, 26.6, 27.3, 2.1],
    [2.3, 2.6, 5.6, 11.4, 0, 38.5, 2.3, 37.5, 38.3, 13],
    [38.9, 39.1, 40.1, 27.9, 38.9, 0, 38.8, 13.6, 12.8, 26.1],
    [0.027, 0.25, 3.3, 11.8, 2.5, 38.9, 0, 37.9, 38.6, 13.3],
    [36.8, 37, 38.1, 25.8, 36.8, 13.5, 36.8, 0, 1, 24],
    [36.8, 37, 38, 25.8, 36.8, 12.8, 36.8, 1.5, 0, 24],
    [13.5, 13.7, 14.8, 2.5, 13.5, 25.5, 13.5, 24.5, 24.4, 0],
]

g.tsp()
# Out:
# Detail jarak (Km) titik satu ke titik lainnya:
# Dari 9 Ke 3, Jarak: 2.5 Km
# Dari 3 Ke 2, Jarak: 12.4 Km
# Dari 2 Ke 1, Jarak: 3 Km
# Dari 1 Ke 0, Jarak: 0.15 Km
# Dari 0 Ke 6, Jarak: 0.064 Km
# Dari 6 Ke 4, Jarak: 2.5 Km
# Dari 4 Ke 7, Jarak: 37.5 Km
# Dari 7 Ke 8, Jarak: 1 Km
# Dari 8 Ke 5, Jarak: 12.8 Km
#
# Rute Terpendek:
# 9 -> 3 -> 2 -> 1 -> 0 -> 6 -> 4 -> 7 -> 8 -> 5
# Total Jarak: 71.914 Km
